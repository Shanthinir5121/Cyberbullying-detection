# %%
pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.5 MB 653.6 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/1.5 MB 1.1 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.2/1.5 MB 1.4 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.5 MB 1.5 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.4/1.5 MB 1.7 MB/s eta 0:00:01
#      -------------- ------------------------- 0.5/1.5 MB 1.9 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.7/1.5 MB 2.1 MB/s eta 0:00:01
#      ------------------- -------------------- 0.7/1.5 MB 1.9 MB/s eta 0:00:01
#      --------------------- ------------------ 0.8/1.5 MB 1.9 MB/s eta 0:00:01
#      ------------------------- -------------- 1.0/1.5 MB 2.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.1/1.5 MB 2.0 MB/s eta 0:00:01
# ...

# %%
import streamlit

# %%
try:
    import streamlit.ReportThread as ReportThread
    from streamlit.server.Server import Server
except Exception:
    # Streamlit >= 0.65.0
    import streamlit.report_thread as ReportThread
    from streamlit.server.server import Server
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 try:
# ----> 2     import streamlit.ReportThread as ReportThread
#       3     from streamlit.server.Server import Server
#
# ModuleNotFoundError: No module named 'streamlit.ReportThread'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       3     from streamlit.server.Server import Server
#       4 except Exception:
#       5     # Streamlit >= 0.65.0
# ----> 6     import streamlit.report_thread as ReportThread
#       7     from streamlit.server.server import Server
#
# ModuleNotFoundError: No module named 'streamlit.report_thread'

# %%
# !pip install watchdog==0.10.2
# Out:
# ...
#      ---------------------------------------- 0.0/95.5 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/95.5 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/95.5 kB ? eta -:--:--
#      ------------ ------------------------- 30.7/95.5 kB 187.9 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/95.5 kB 273.8 kB/s eta 0:00:01
# ...

# %%
# !pip install --upgrade streamlit
# Out:
# ...
#   Using cached streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
# ...
#   Using cached streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
# ...
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install firebase
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install flask

# !pip install streamlit
# !pip install sqlite3
# Out:
# ...
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.9 kB ? eta -:--:--
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
#      --------------------------------- ------ 81.9/96.9 kB 1.6 MB/s eta 0:00:01
# ...

# %%
# !pip install pyrebase
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade requests
# Out:
# ...
#
# ...
#   Using cached requests-2.30.0-py3-none-any.whl (62 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.11.1
#     Uninstalling requests-2.11.1:
#       Successfully uninstalled requests-2.11.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase 3.0.27 requires requests==2.11.1, but you have requests 2.30.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install requests==2.11.1
# Out:
# ...
#   Using cached requests-2.11.1-py2.py3-none-any.whl (514 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.30.0
#     Uninstalling requests-2.30.0:
#       Successfully uninstalled requests-2.30.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# favicon 0.7.0 requires requests>=2.21.0, but you have requests 2.11.1 which is incompatible.
# jupyterlab-server 2.19.0 requires requests>=2.28, but you have requests 2.11.1 which is incompatible.
# tensorboard 2.12.0 requires requests<3,>=2.21.0, but you have requests 2.11.1 which is incompatible.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pyrebase4
# Out:
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Using cached gcloud-0.18.3-py3-none-any.whl
# ...
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# ...
#   Using cached pycryptodome-3.17-cp35-abi3-win_amd64.whl (1.7 MB)
# ...
#   Attempting uninstall: pycryptodome
#     Found existing installation: pycryptodome 3.4.3
#     Uninstalling pycryptodome-3.4.3:
#       Successfully uninstalled pycryptodome-3.4.3
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.7.0
#     Uninstalling requests-toolbelt-0.7.0:
#       Successfully uninstalled requests-toolbelt-0.7.0
#   Attempting uninstall: oauth2client
#     Found existing installation: oauth2client 3.0.0
#     Uninstalling oauth2client-3.0.0:
#       Successfully uninstalled oauth2client-3.0.0
#   Attempting uninstall: gcloud
#     Found existing installation: gcloud 0.17.0
#     Uninstalling gcloud-0.17.0:
#       Successfully uninstalled gcloud-0.17.0
# ...

# %%
pip install oauth2client==3.0.0
# Out:
# ...
#
#   Using cached oauth2client-3.0.0-py3-none-any.whl
# ...
#   Attempting uninstall: oauth2client
#     Found existing installation: oauth2client 4.1.3
#     Uninstalling oauth2client-4.1.3:
#       Successfully uninstalled oauth2client-4.1.3
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase 3.0.27 requires gcloud==0.17.0, but you have gcloud 0.18.3 which is incompatible.
# pyrebase 3.0.27 requires pycryptodome==3.4.3, but you have pycryptodome 3.17 which is incompatible.
# pyrebase 3.0.27 requires requests==2.11.1, but you have requests 2.19.1 which is incompatible.
# pyrebase 3.0.27 requires requests-toolbelt==0.7.0, but you have requests-toolbelt 1.0.0 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# ...

# %%
pip install requests-toolbelt==0.7.0
# Out:
# ...
#
#   Using cached requests_toolbelt-0.7.0-py2.py3-none-any.whl (52 kB)
# ...
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 1.0.0
#     Uninstalling requests-toolbelt-1.0.0:
#       Successfully uninstalled requests-toolbelt-1.0.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase 3.0.27 requires gcloud==0.17.0, but you have gcloud 0.18.3 which is incompatible.
# pyrebase 3.0.27 requires pycryptodome==3.4.3, but you have pycryptodome 3.17 which is incompatible.
# pyrebase 3.0.27 requires requests==2.11.1, but you have requests 2.19.1 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
# pyrebase4 4.6.0 requires requests-toolbelt>=0.7.1, but you have requests-toolbelt 0.7.0 which is incompatible.
#
# ...

# %%
pip install requests==2.11.1
# Out:
# ...
#   Using cached requests-2.11.1-py2.py3-none-any.whl (514 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.19.1
#     Uninstalling requests-2.19.1:
#       Successfully uninstalled requests-2.19.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# favicon 0.7.0 requires requests>=2.21.0, but you have requests 2.11.1 which is incompatible.
# jupyterlab-server 2.19.0 requires requests>=2.28, but you have requests 2.11.1 which is incompatible.
# pyrebase 3.0.27 requires gcloud==0.17.0, but you have gcloud 0.18.3 which is incompatible.
# pyrebase 3.0.27 requires pycryptodome==3.4.3, but you have pycryptodome 3.17 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
# ...

# %%
pip install gcloud==0.17.0
# Out:
# ...
#   Using cached gcloud-0.17.0-py3-none-any.whl
# ...
#   Attempting uninstall: gcloud
#     Found existing installation: gcloud 0.18.3
#     Uninstalling gcloud-0.18.3:
#       Successfully uninstalled gcloud-0.18.3
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase4 4.6.0 requires gcloud>=0.18.3, but you have gcloud 0.17.0 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
# pyrebase4 4.6.0 requires pycryptodome>=3.6.4, but you have pycryptodome 3.4.3 which is incompatible.
# pyrebase4 4.6.0 requires requests>=2.19.1, but you have requests 2.11.1 which is incompatible.
# pyrebase4 4.6.0 requires requests-toolbelt>=0.7.1, but you have requests-toolbelt 0.7.0 which is incompatible.
#
# ...

# %%
pip install pycryptodome==3.4.3
# Out:
# ...
#   Using cached pycryptodome-3.4.3-cp311-cp311-win_amd64.whl
# ...
#   Attempting uninstall: pycryptodome
#     Found existing installation: pycryptodome 3.17
#     Uninstalling pycryptodome-3.17:
#       Successfully uninstalled pycryptodome-3.17
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase 3.0.27 requires gcloud==0.17.0, but you have gcloud 0.18.3 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
# pyrebase4 4.6.0 requires pycryptodome>=3.6.4, but you have pycryptodome 3.4.3 which is incompatible.
# pyrebase4 4.6.0 requires requests>=2.19.1, but you have requests 2.11.1 which is incompatible.
# pyrebase4 4.6.0 requires requests-toolbelt>=0.7.1, but you have requests-toolbelt 0.7.0 which is incompatible.
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyrebase4
#
# ModuleNotFoundError: No module named 'pyrebase4'

# %%
pip install --upgrade gcloud==0.18.3 oauth2client==4.1.3 pycryptodome==3.10.1 requests==2.26.0 requests-toolbelt==0.9.1
# Out:
# ...
#   Using cached gcloud-0.18.3-py3-none-any.whl
# ...
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# ...
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.6 MB 1.3 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.6 MB 1.3 MB/s eta 0:00:02
#      -- ------------------------------------- 0.1/1.6 MB 871.5 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.6 MB 654.9 kB/s eta 0:00:03
#      --- ------------------------------------ 0.2/1.6 MB 706.2 kB/s eta 0:00:03
#      --- ------------------------------------ 0.2/1.6 MB 706.2 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.6 MB 687.0 kB/s eta 0:00:03
#      ------- -------------------------------- 0.3/1.6 MB 883.3 kB/s eta 0:00:02
#      ------- -------------------------------- 0.3/1.6 MB 759.5 kB/s eta 0:00:02
# ...

# %%
pip install requests-toolbelt==0.7.0
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrebase4 4.6.0 requires gcloud>=0.18.3, but you have gcloud 0.17.0 which is incompatible.
# pyrebase4 4.6.0 requires oauth2client>=4.1.2, but you have oauth2client 3.0.0 which is incompatible.
# pyrebase4 4.6.0 requires pycryptodome>=3.6.4, but you have pycryptodome 3.4.3 which is incompatible.
# pyrebase4 4.6.0 requires requests>=2.19.1, but you have requests 2.11.1 which is incompatible.
# pyrebase4 4.6.0 requires requests-toolbelt>=0.7.1, but you have requests-toolbelt 0.7.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached requests_toolbelt-0.7.0-py2.py3-none-any.whl (52 kB)
# ...
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.7.1
# ...

# %%
pip install streamlit_extras
# Out:
# ...
#      ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/48.8 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 48.8/48.8 kB 414.5 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/679.4 kB ? eta -:--:--
#      -- ------------------------------------- 41.0/679.4 kB ? eta -:--:--
#      -- ------------------------------------- 41.0/679.4 kB ? eta -:--:--
#      -- ------------------------------------- 41.0/679.4 kB ? eta -:--:--
#      -- ------------------------------------- 41.0/679.4 kB ? eta -:--:--
#      ---------- ------------------------- 194.6/679.4 kB 841.6 kB/s eta 0:00:01
#      --------------- ---------------------- 276.5/679.4 kB 1.1 MB/s eta 0:00:01
# ...

# %%
# pip uninstall requests_toolbelt
# !pip install requests_toolbelt==0.9.1
# Out:
# ...
#      ---------------------------------------- 0.0/54.3 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/54.3 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/54.3 kB ? eta -:--:--
#      --------------------- ---------------- 30.7/54.3 kB 187.9 kB/s eta 0:00:01
#      --------------------- ---------------- 30.7/54.3 kB 187.9 kB/s eta 0:00:01
#      --------------------- ---------------- 30.7/54.3 kB 187.9 kB/s eta 0:00:01
#      -------------------------------------- 54.3/54.3 kB 166.3 kB/s eta 0:00:00
# ...
#   Attempting uninstall: requests_toolbelt
#     Found existing installation: requests-toolbelt 1.0.0
#     Uninstalling requests-toolbelt-1.0.0:
#       Successfully uninstalled requests-toolbelt-1.0.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
pip install torch torchvision torchaudio
# Out:
# ...
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      -------------------------------------- 0.1/172.3 MB 812.7 kB/s eta 0:03:32
#      ---------------------------------------- 0.2/172.3 MB 1.3 MB/s eta 0:02:13
#      ---------------------------------------- 0.2/172.3 MB 1.3 MB/s eta 0:02:12
#      ---------------------------------------- 0.4/172.3 MB 1.8 MB/s eta 0:01:38
#      ---------------------------------------- 0.5/172.3 MB 1.8 MB/s eta 0:01:36
#      ---------------------------------------- 0.6/172.3 MB 2.0 MB/s eta 0:01:25
#      ---------------------------------------- 0.8/172.3 MB 2.2 MB/s eta 0:01:20
#      ---------------------------------------- 0.9/172.3 MB 2.3 MB/s eta 0:01:14
#      ---------------------------------------- 1.1/172.3 MB 2.4 MB/s eta 0:01:12
#      ---------------------------------------- 1.2/172.3 MB 2.5 MB/s eta 0:01:09
# ...

# %%
pip install --upgrade pyrebase
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\aksha\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\~rypto\\Hash\\_SHA256.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached gcloud-0.17.0-py3-none-any.whl
# ...
#   Using cached oauth2client-3.0.0-py3-none-any.whl
# ...
#   Using cached pycryptodome-3.4.3-cp311-cp311-win_amd64.whl
# ...
#   Using cached requests-2.11.1-py2.py3-none-any.whl (514 kB)
# ...
#   Using cached requests_toolbelt-0.7.0-py2.py3-none-any.whl (52 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.30.0
#     Uninstalling requests-2.30.0:
#       Successfully uninstalled requests-2.30.0
#   Attempting uninstall: pycryptodome
#     Found existing installation: pycryptodome 3.17
#     Uninstalling pycryptodome-3.17:
# ...

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      --- --------------------------------- 30.7/293.3 kB 660.6 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/293.3 kB 871.5 kB/s eta 0:00:01
#      ------------- ---------------------- 112.6/293.3 kB 819.2 kB/s eta 0:00:01
#      ----------------- ------------------ 143.4/293.3 kB 853.3 kB/s eta 0:00:01
#      ----------------------- ------------ 194.6/293.3 kB 908.0 kB/s eta 0:00:01
#      ----------------------------------- -- 276.5/293.3 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached wordcloud-1.8.2.2.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# ...
#   Running setup.py install for wordcloud: started
#   Running setup.py install for wordcloud: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [26 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-cpython-311\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-cpython-311\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-cpython-311\wordcloud
# ...

# %%
pip install wordcloud -version-compatible-operatingsystem
# Out:
# Using pip 23.0.1 from C:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip (python 3.11)Note: you may need to restart the kernel to use updated packages.
# ERROR: rsion-compatible-operatingsystem is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import os
#       2 import matplotlib.pyplot as plt
# ----> 3 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aksha\AppData\Local\Programs\Python\Python311\python.exe

# %%
'C:\\Users\\aksha\\AppData\\Local\\Programs\\Python\\Python311\\python.exe'/bin/python -m pip install wordcloud
# Out:
#   Cell In[7], line 1
#     'C:\\Users\\aksha\\AppData\\Local\\Programs\\Python\\Python311\\python.exe'/bin/python -m pip install wordcloud
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
python -m pip install wordcloud
# Out:
#   Cell In[4], line 1
#     python -m pip install wordcloud
#               ^
# SyntaxError: invalid syntax

# %%
pip install streamlit_chat
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#      - -------------------------------------- 0.1/1.7 MB 126.1 kB/s eta 0:00:13
#      -- ------------------------------------- 0.1/1.7 MB 163.8 kB/s eta 0:00:10
# ...

# %%
import time
